# %%
# %load_ext autoreload
# %autoreload 2
import torch
import random

from sae.sparse_autoencoder import load_saved_sae
from sae.metrics import model_store_from_sae
from unlearning.metrics import convert_wmdp_data_to_prompt
from unlearning.tool import UnlearningConfig, SAEUnlearningTool, MCQ_ActivationStoreAnalysis

from huggingface_hub import hf_hub_download
from datasets import load_dataset
import numpy as np
import pandas as pd
import itertools

from jaxtyping import Float
from torch import Tensor

import plotly.express as px

# %%
# resid pre 9
REPO_ID = "eoinf/unlearning_saes"
FILENAME = "jolly-dream-40/sparse_autoencoder_gemma-2b-it_blocks.9.hook_resid_pre_s16384_127995904.pt"


filename = hf_hub_download(repo_id=REPO_ID, filename=FILENAME)
sae = load_saved_sae(filename)

model = model_store_from_sae(sae)
# Out:
# `config.hidden_act` is ignored, you should use `config.hidden_activation` instead.
# Gemma's activation function will be set to `gelu_pytorch_tanh`. Please, use
# `config.hidden_activation` if you want to override this behaviour.
# See https://github.com/huggingface/transformers/pull/29402 for more details.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# WARNING:root:You are not using LayerNorm, so the writing weights can't be centered! Skipping
# Loaded pretrained model gemma-2b-it into HookedTransformer
# Moving model to device:  cuda

# %%
# read 172 questions that the model can answer correctly in any permutation
filename = '../data/wmdp-bio_gemma_2b_it_correct.csv'
correct_question_ids = np.genfromtxt(filename)


# read 133 questions that the model can answer correctly in any permutation but will get it wrong if
# without the instruction prompt and the question prompt
filename = '../data/wmdp-bio_gemma_2b_it_correct_not_correct_wo_question_prompt.csv'
correct_question_id_not_correct_wo_question_prompt = np.genfromtxt(filename)

# %%
dataset = load_dataset("cais/wmdp", "wmdp-bio")
permute_choices = None
prompts = [convert_wmdp_data_to_prompt(dataset['test'][i]['question'], dataset['test'][i]['choices'], prompt_format=None, permute_choices=permute_choices) for i in range(len(dataset['test'])) if i in correct_question_id_not_correct_wo_question_prompt]

# %%
# setup unlearning tool, need about 3 minutes to run this cell

filename = "../data/wmdp-bio_gemma_2b_it_correct.csv"
correct_question_ids = np.genfromtxt(filename)
all_permutations = list(itertools.permutations([0, 1, 2, 3]))
n_questions = 10

dataset_args = {
    'question_subset': correct_question_ids[:n_questions],
    'permutations': all_permutations,
}

n_batches = n_questions * len(all_permutations) // 4
sae.cfg.n_batches_in_store_buffer = n_batches * 2
unlearn_activation_store = MCQ_ActivationStoreAnalysis(sae.cfg, model, dataset_args=dataset_args)
unlearning_metric = 'wmdp-bio_gemma_2b_it_correct'


unlearn_cfg = UnlearningConfig(unlearn_activation_store=unlearn_activation_store, unlearning_metric=unlearning_metric)
ul_tool = SAEUnlearningTool(unlearn_cfg)
ul_tool.setup()
ul_tool.get_metrics_with_text(n_batches=n_batches)
# Out:
# dataloader
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# WARNING:root:You are not using LayerNorm, so the writing weights can't be centered! Skipping
# Loaded pretrained model gemma-2b-it into HookedTransformer
# Moving model to device:  cuda
# buffer
# dataloader
# 100%|██████████| 60/60 [00:29<00:00,  2.03it/s]
# tokens torch.Size([240, 1024]) 1024
# tokens torch.Size([240, 1024])
# Concatenating learned activations
# Done
# 100%|██████████| 60/60 [00:08<00:00,  7.20it/s]
# tokens torch.Size([240, 1024]) 1024
# tokens torch.Size([240, 1024])
# Concatenating learned activations
# Done

# %%
answers = [p.index(dataset['test'][i]['answer']) for i in range(len(dataset['test'])) if i in correct_question_ids[:n_questions] for p in all_permutations]
answers
# Out:
# [3,
#  2,
#  3,
#  2,
#  1,
#  1,
#  3,
#  2,
#  3,
#  2,
#  1,
#  1,
#  3,
#  2,
#  3,
#  2,
#  1,
#  1,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  3,
#  2,
#  3,
#  2,
#  1,
#  1,
#  3,
#  2,
#  3,
#  2,
#  1,
#  1,
#  3,
#  2,
#  3,
#  2,
#  1,
#  1,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  3,
#  2,
#  3,
#  2,
#  1,
#  1,
#  3,
#  2,
#  3,
#  2,
#  1,
#  1,
#  3,
#  2,
#  3,
#  2,
#  1,
#  1,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  1,
#  1,
#  2,
#  3,
#  2,
#  3,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  2,
#  3,
#  1,
#  1,
#  3,
#  2,
#  2,
#  3,
#  1,
#  1,
#  3,
#  2,
#  3,
#  2,
#  3,
#  2,
#  1,
#  1,
#  3,
#  2,
#  3,
#  2,
#  1,
#  1,
#  3,
#  2,
#  3,
#  2,
#  1,
#  1,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  3,
#  2,
#  3,
#  2,
#  1,
#  1,
#  3,
#  2,
#  3,
#  2,
#  1,
#  1,
#  3,
#  2,
#  3,
#  2,
#  1,
#  1,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  1,
#  1,
#  2,
#  3,
#  2,
#  3,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  2,
#  3,
#  1,
#  1,
#  3,
#  2,
#  2,
#  3,
#  1,
#  1,
#  3,
#  2,
#  3,
#  2,
#  3,
#  2,
#  1,
#  1,
#  3,
#  2,
#  3,
#  2,
#  1,
#  1,
#  3,
#  2,
#  3,
#  2,
#  1,
#  1,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  2,
#  3,
#  1,
#  1,
#  3,
#  2,
#  2,
#  3,
#  1,
#  1,
#  3,
#  2,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  3,
#  2,
#  3,
#  2,
#  1,
#  1,
#  3,
#  2,
#  3,
#  2,
#  1,
#  1,
#  3,
#  2,
#  3,
#  2,
#  1,
#  1,
#  3,
#  2,
#  3,
#  2,
#  1,
#  1,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0]

# %%
unlearn_metrics = ul_tool.unlearn_metrics_with_text

# %%
unlearn_metrics['learned_activations'].shape
# Out:
# torch.Size([245760, 16384])

# %%
unlearn_metrics['token_df'].query('batch == 0').query('pos >= 16')
# Out:
#        str_tokens    unique_token                                    context  \
# 16    ·explaining  ·explaining/16      ·about·biology.↩\nIn|·explaining|·the
# 17           ·the         ·the/17      ·biology.↩\nIn·explaining|·the|·known
# 18         ·known       ·known/18      .↩\nIn·explaining·the|·known|·methods
# 19       ·methods     ·methods/19   ↩\nIn·explaining·the·known|·methods|·for
# 20           ·for         ·for/20  In·explaining·the·known·methods|·for|·the
# ...           ...             ...                                        ...
# 1019        <pad>      <pad>/1019      <pad><pad><pad><pad><pad>|<pad>|<pad>
# 1020        <pad>      <pad>/1020      <pad><pad><pad><pad><pad>|<pad>|<pad>
# 1021        <pad>      <pad>/1021      <pad><pad><pad><pad><pad>|<pad>|<pad>
# 1022        <pad>      <pad>/1022           <pad><pad><pad><pad><pad>|<pad>|
# 1023        <pad>      <pad>/1023           <pad><pad><pad><pad><pad>|<pad>|
#
#                                prefix    suffix  batch   pos   label
# 16               ·about·biology.↩\nIn      ·the      0    16    0/16
# 17          ·biology.↩\nIn·explaining    ·known      0    17    0/17
# 18              .↩\nIn·explaining·the  ·methods      0    18    0/18
# 19         ↩\nIn·explaining·the·known      ·for      0    19    0/19
# 20    In·explaining·the·known·methods      ·the      0    20    0/20
# ...                               ...       ...    ...   ...     ...
# 1019        <pad><pad><pad><pad><pad>     <pad>      0  1019  0/1019
# 1020        <pad><pad><pad><pad><pad>     <pad>      0  1020  0/1020
# 1021        <pad><pad><pad><pad><pad>     <pad>      0  1021  0/1021
# 1022        <pad><pad><pad><pad><pad>                0  1022  0/1022
# 1023        <pad><pad><pad><pad><pad>                0  1023  0/1023
#
# [1008 rows x 8 columns]

# %%
learned_activations_reshape: Float[Tensor, 'n_permutations seq_len n_features'] = unlearn_metrics['learned_activations'].reshape(-1, 1024, 16384)

# %%
# (learned_activations_reshape[1] == unlearn_metrics['learned_activations'][1024:2048]).all()

max_activations = learned_activations_reshape.max(axis=1).values
max_activations.shape

# group by ans: 0, 1, 2, 3
answers = torch.tensor(answers)
max_activations_grouped = [max_activations[answers == i] for i in range(4)]
max_activations_grouped = torch.stack(max_activations_grouped)
print(max_activations_grouped.shape)
# Out:
# torch.Size([4, 60, 16384])

# %%
max_activations_grouped_mean = max_activations_grouped.mean(axis=1)
print(max_activations_grouped_mean.shape)
# Out:
# torch.Size([4, 16384])

# %%
feature_act_diff_B_to_all = max_activations_grouped_mean[1] - max_activations_grouped_mean.mean(axis=0)
feature_act_diff_B_to_all.shape
# Out:
# torch.Size([16384])

# %%
# get feature index if non zero
non_zero_indices = feature_act_diff_B_to_all.nonzero()
non_zero_values = feature_act_diff_B_to_all[non_zero_indices].squeeze()
# px.histogram(feature_act_diff_B_to_all, title='Feature Activation Difference B to All')

# %%
feature_act_diff_B_to_all.to(float).topk(10)
# Out:
# torch.return_types.topk(
# values=tensor([0.2812, 0.1387, 0.1230, 0.1211, 0.1206, 0.1094, 0.1021, 0.0918, 0.0918,
#         0.0918], dtype=torch.float64),
# indices=tensor([ 9992,  9399, 10046, 10159,  7320, 15062, 11821, 15691, 13718, 13309]))

# %%
from transformer_lens import utils

feature_id = 833
print(f'Feature ID: {feature_id}')

unlearn_metrics['token_df']["feature"] = utils.to_numpy(unlearn_metrics['learned_activations'][:, feature_id])
unlearn_metrics['token_df']['answer'] = np.array(answers).repeat(1024)
df = unlearn_metrics['token_df'][['str_tokens','prefix', 'suffix',  'context', 'batch', 'pos', 'feature', 'answer']].query("feature > 0")#.query("batch == 68")
df.sort_values("feature", ascending=False).head(100).style.background_gradient("coolwarm")
# Out:
# Feature ID: 833
# <style type="text/css">
# #T_b8aa2_row0_col4, #T_b8aa2_row87_col4 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_b8aa2_row0_col5, #T_b8aa2_row1_col5, #T_b8aa2_row2_col5, #T_b8aa2_row3_col5, #T_b8aa2_row4_col5, #T_b8aa2_row5_col5 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_b8aa2_row0_col6, #T_b8aa2_row0_col7, #T_b8aa2_row1_col6, #T_b8aa2_row2_col6, #T_b8aa2_row2_col7, #T_b8aa2_row3_col6, #T_b8aa2_row4_col6, #T_b8aa2_row5_col6, #T_b8aa2_row6_col7, #T_b8aa2_row10_col7, #T_b8aa2_row18_col7, #T_b8aa2_row21_col7, #T_b8aa2_row25_col7, #T_b8aa2_row27_col7, #T_b8aa2_row30_col7, #T_b8aa2_row33_col7, #T_b8aa2_row37_col7, #T_b8aa2_row38_col7, #T_b8aa2_row42_col7, #T_b8aa2_row48_col7, #T_b8aa2_row50_col7, #T_b8aa2_row52_col7, #T_b8aa2_row55_col7, #T_b8aa2_row58_col7, #T_b8aa2_row61_col7, #T_b8aa2_row63_col7, #T_b8aa2_row72_col4, #T_b8aa2_row82_col7, #T_b8aa2_row87_col7, #T_b8aa2_row91_col5, #T_b8aa2_row92_col5, #T_b8aa2_row93_col5, #T_b8aa2_row96_col7, #T_b8aa2_row99_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b8aa2_row1_col4, #T_b8aa2_row75_col4, #T_b8aa2_row88_col4 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_b8aa2_row1_col7, #T_b8aa2_row4_col7, #T_b8aa2_row8_col7, #T_b8aa2_row9_col7, #T_b8aa2_row22_col7, #T_b8aa2_row23_col7, #T_b8aa2_row28_col7, #T_b8aa2_row29_col7, #T_b8aa2_row31_col7, #T_b8aa2_row32_col7, #T_b8aa2_row39_col7, #T_b8aa2_row40_col7, #T_b8aa2_row51_col7, #T_b8aa2_row54_col7, #T_b8aa2_row59_col7, #T_b8aa2_row62_col7, #T_b8aa2_row64_col7, #T_b8aa2_row65_col7, #T_b8aa2_row66_col7, #T_b8aa2_row75_col7, #T_b8aa2_row76_col7, #T_b8aa2_row81_col7, #T_b8aa2_row88_col7, #T_b8aa2_row90_col7, #T_b8aa2_row91_col7, #T_b8aa2_row98_col7 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_b8aa2_row2_col4, #T_b8aa2_row3_col7, #T_b8aa2_row5_col7, #T_b8aa2_row7_col7, #T_b8aa2_row11_col7, #T_b8aa2_row19_col7, #T_b8aa2_row20_col7, #T_b8aa2_row24_col7, #T_b8aa2_row26_col7, #T_b8aa2_row34_col7, #T_b8aa2_row35_col7, #T_b8aa2_row36_col7, #T_b8aa2_row41_col7, #T_b8aa2_row43_col7, #T_b8aa2_row48_col4, #T_b8aa2_row49_col7, #T_b8aa2_row53_col7, #T_b8aa2_row56_col7, #T_b8aa2_row57_col7, #T_b8aa2_row60_col7, #T_b8aa2_row83_col7, #T_b8aa2_row84_col7, #T_b8aa2_row85_col7, #T_b8aa2_row86_col7, #T_b8aa2_row95_col7, #T_b8aa2_row97_col7 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_b8aa2_row3_col4, #T_b8aa2_row20_col5, #T_b8aa2_row21_col5, #T_b8aa2_row48_col5, #T_b8aa2_row49_col4, #T_b8aa2_row49_col5 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_b8aa2_row4_col4, #T_b8aa2_row76_col4 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_b8aa2_row5_col4, #T_b8aa2_row86_col4 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_b8aa2_row6_col4, #T_b8aa2_row21_col4 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_b8aa2_row6_col5, #T_b8aa2_row7_col5, #T_b8aa2_row8_col5, #T_b8aa2_row9_col5, #T_b8aa2_row10_col5, #T_b8aa2_row11_col5, #T_b8aa2_row38_col6, #T_b8aa2_row39_col6, #T_b8aa2_row40_col6, #T_b8aa2_row41_col6, #T_b8aa2_row42_col6, #T_b8aa2_row43_col6 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_b8aa2_row6_col6, #T_b8aa2_row7_col6, #T_b8aa2_row8_col6, #T_b8aa2_row9_col6, #T_b8aa2_row10_col6, #T_b8aa2_row11_col6 {
#   background-color: #d85646;
#   color: #f1f1f1;
# }
# #T_b8aa2_row7_col4, #T_b8aa2_row20_col4 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_b8aa2_row8_col4, #T_b8aa2_row64_col4, #T_b8aa2_row81_col4 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_b8aa2_row9_col4, #T_b8aa2_row65_col4 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_b8aa2_row10_col4, #T_b8aa2_row63_col4 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_b8aa2_row11_col4, #T_b8aa2_row85_col4 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_b8aa2_row12_col4, #T_b8aa2_row46_col4, #T_b8aa2_row89_col4 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_b8aa2_row12_col5, #T_b8aa2_row13_col5, #T_b8aa2_row14_col5, #T_b8aa2_row15_col5, #T_b8aa2_row16_col5, #T_b8aa2_row17_col5 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_b8aa2_row12_col6, #T_b8aa2_row13_col6, #T_b8aa2_row14_col6, #T_b8aa2_row15_col6, #T_b8aa2_row16_col6, #T_b8aa2_row17_col6 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_b8aa2_row12_col7, #T_b8aa2_row13_col7, #T_b8aa2_row14_col7, #T_b8aa2_row15_col7, #T_b8aa2_row16_col7, #T_b8aa2_row17_col7, #T_b8aa2_row22_col5, #T_b8aa2_row23_col5, #T_b8aa2_row24_col5, #T_b8aa2_row25_col5, #T_b8aa2_row26_col5, #T_b8aa2_row27_col5, #T_b8aa2_row44_col7, #T_b8aa2_row45_col7, #T_b8aa2_row46_col7, #T_b8aa2_row47_col7, #T_b8aa2_row67_col7, #T_b8aa2_row68_col7, #T_b8aa2_row69_col7, #T_b8aa2_row70_col7, #T_b8aa2_row71_col7, #T_b8aa2_row72_col7, #T_b8aa2_row73_col7, #T_b8aa2_row74_col7, #T_b8aa2_row77_col7, #T_b8aa2_row78_col7, #T_b8aa2_row79_col7, #T_b8aa2_row80_col7, #T_b8aa2_row82_col4, #T_b8aa2_row89_col7, #T_b8aa2_row92_col7, #T_b8aa2_row93_col7, #T_b8aa2_row94_col7, #T_b8aa2_row96_col6, #T_b8aa2_row97_col6, #T_b8aa2_row98_col6, #T_b8aa2_row99_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_b8aa2_row13_col4, #T_b8aa2_row77_col4 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_b8aa2_row14_col4, #T_b8aa2_row44_col4, #T_b8aa2_row80_col4 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_b8aa2_row15_col4, #T_b8aa2_row47_col4 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_b8aa2_row16_col4, #T_b8aa2_row92_col4, #T_b8aa2_row94_col4 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_b8aa2_row17_col4, #T_b8aa2_row45_col4, #T_b8aa2_row93_col4 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_b8aa2_row18_col4, #T_b8aa2_row30_col4, #T_b8aa2_row96_col4 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_b8aa2_row18_col5, #T_b8aa2_row19_col5, #T_b8aa2_row27_col4, #T_b8aa2_row86_col5, #T_b8aa2_row87_col5 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_b8aa2_row18_col6, #T_b8aa2_row19_col6 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_b8aa2_row19_col4, #T_b8aa2_row34_col4, #T_b8aa2_row95_col4 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_b8aa2_row20_col6, #T_b8aa2_row21_col6 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_b8aa2_row22_col4, #T_b8aa2_row46_col5, #T_b8aa2_row47_col5, #T_b8aa2_row75_col5, #T_b8aa2_row76_col5 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_b8aa2_row22_col6, #T_b8aa2_row23_col6, #T_b8aa2_row24_col6, #T_b8aa2_row25_col6, #T_b8aa2_row26_col6, #T_b8aa2_row27_col6 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_b8aa2_row23_col4 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_b8aa2_row24_col4 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_b8aa2_row25_col4, #T_b8aa2_row36_col5, #T_b8aa2_row37_col5 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_b8aa2_row26_col4 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_b8aa2_row28_col4, #T_b8aa2_row31_col4, #T_b8aa2_row66_col4 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_b8aa2_row28_col5, #T_b8aa2_row29_col5 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_b8aa2_row28_col6, #T_b8aa2_row29_col6, #T_b8aa2_row30_col6, #T_b8aa2_row31_col6, #T_b8aa2_row32_col6, #T_b8aa2_row33_col6, #T_b8aa2_row34_col6, #T_b8aa2_row35_col6 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_b8aa2_row29_col4, #T_b8aa2_row32_col4, #T_b8aa2_row90_col4, #T_b8aa2_row91_col4 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_b8aa2_row30_col5, #T_b8aa2_row31_col5, #T_b8aa2_row32_col5, #T_b8aa2_row33_col5, #T_b8aa2_row34_col5, #T_b8aa2_row35_col5 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_b8aa2_row33_col4, #T_b8aa2_row37_col4, #T_b8aa2_row50_col4, #T_b8aa2_row66_col5, #T_b8aa2_row77_col5, #T_b8aa2_row95_col5 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_b8aa2_row35_col4, #T_b8aa2_row36_col4, #T_b8aa2_row84_col4 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_b8aa2_row36_col6, #T_b8aa2_row37_col6 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_b8aa2_row38_col4 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_b8aa2_row38_col5, #T_b8aa2_row39_col5, #T_b

# %%
import torch
import numpy as np

# Original list
original_list = [0, 1, 2, 3, 4, 4, 1, 2, 2, 2]

# Convert the original list to a NumPy array
original_array = np.array(original_list)

# Use NumPy's repeat function to repeat each element 1024 times
repeated_array = original_array.repeat(, 3)

# Convert the resulting NumPy array to a PyTorch tensor
repeated_tensor = torch.tensor(repeated_array)

print(repeated_tensor)  # Should be [10240]
# Out:
# tensor([0, 1, 2, 3, 4, 4, 1, 2, 2, 2, 0, 1, 2, 3, 4, 4, 1, 2, 2, 2, 0, 1, 2, 3,
#         4, 4, 1, 2, 2, 2])
# /tmp/ipykernel_1698/2887232628.py:14: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   repeated_tensor = torch.tensor(repeated_array)

# %%
# Out:
# tensor([2980., 2467.,  903.,  ...,    0.,    0.,    0.], device='cuda:0')
